# %% [markdown]
# <a href="https://colab.research.google.com/github/KarlaSaenz128/EPPL-Area-y-pertimetro-de-un-circulo-mis-imagenes/blob/main/El_profe_circulo_Karla_Saenz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Karla Saenz NL =48 fecha 25/mar/2026
# ---
# # Calcular Area y perimetro de un circulo
# ---
# ![logo de markdrow](https://raw.githubusercontent.com/KarlaSaenz128/EPPL-Area-y-pertimetro-de-un-circulo-mis-imagenes/refs/heads/main/circulo.PNG)
# ---
# ## Formula para cslcular area
# $A=\pi*r^2$
# ---
# ## formula para calcular perimetro
# * $P=2*\pi*r$
# ## Datos de entrada
# $r$ ?
#
# ---
#
# #Diagrama de flujo en lucichat
# ![Logo de Markdown](https://raw.githubusercontent.com/KarlaSaenz128/EPPL-Area-y-pertimetro-de-un-circulo-mis-imagenes/refs/heads/main/DF%20Area%20perimetro%20circulo.png)

# %%
# Calcular area y perimetro de un circulo
# variables A,P,r
# formulas A = pi*r^2 y P = 2 * pi * r
# capturar el valor de r}
import math
print("Calcular area y perimetro de un circulo")
r = float(input("Ingrese el valor del radio: "))
A =math.pi*r
P = 2*math.pi*r
print("El area del circulo es: ",A)
print("El perimetro del circulo es:",P)
print("Karla Saenz NL = 48")
# Out:
# Calcular area y perimetro de un circulo
# Ingrese el valor del radio: 3
# El area del circulo es:  9.42477796076938
# El perimetro del circulo es: 18.84955592153876
# Karla Saenz NL = 48

# %% [markdown]
# # Relacion entre codigo y DF en tldraw
# ![formulas de codigos] ![Texto descriptivo](https://raw.githubusercontent.com/KarlaSaenz128/EPPL-Area-y-pertimetro-de-un-circulo-mis-imagenes/refs/heads/main/image.png)
